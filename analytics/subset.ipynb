# %%
import pandas as pd

# %%
# 데이터 프레임 생성
sample_df = pd.read_excel("./data/sample.xlsx")
sample_df
# Out:
#    Sap Co.        대리점 영업사원       전월       금월  TEAM  총 판매수량
# 0   KI1316    경기수원대리점  이기정  1720000  2952000     1     123
# 1   KI1451    충청홍성대리점  정미진  4080000  2706000     2     220
# 2   KI1534    경기화성대리점  경인선   600000  2214000     1     320
# 3   KI1636    강원속초대리점  이동권  3720000  2870000     3     110
# 4   KI1735    경기안양대리점  강준석  4800000  2296000     1     134
# 5   KI1875   제주제주시대리점  민경수  3420000  2346000     4     210
# 6   KI1917    경기광주대리점  김진혜  1292000  1518000     1     110
# 7   KI2032    경기평택대리점  고유정  2736000  2139000     2      90
# 8   KI2153   경기의정부대리점  김은향  1368000  2484000     1     183
# 9   KI2214    경기성남대리점  이준수  1976000  1518000     3      73
# 10  KI2313  제주서귀포시대리점  온지수   152000   945000     1      52
# 11  KI2433    경기계양대리점  이희영  1833000  1404000     1     110
# 12  KI2512    경기평촌대리점  강백호  4320000  2312000     3     240
# 13  KI2671  제주서귀포시대리점  주은명  4040000  4760000     4      50
# 14  KI2776   경기남양주대리점  김수진  8160000  4352000     2     354
# ...

# %%
# 앞에서 5 행 조회

sample_df.head()

sample_df.head(2)
# Out:
#   Sap Co.      대리점 영업사원       전월       금월  TEAM  총 판매수량
# 0  KI1316  경기수원대리점  이기정  1720000  2952000     1     123
# 1  KI1451  충청홍성대리점  정미진  4080000  2706000     2     220

# %%
# 뒤에서 5 행 조회

sample_df.tail()

sample_df.tail(3)
# Out:
#    Sap Co.      대리점 영업사원       전월       금월  TEAM  총 판매수량
# 17  KI3030  강원영동대리점  전수창  4560000  3128000     2      98
# 18  KI3131  경기하남대리점  김민정  2750000  7268000     3     293
# 19  KI3252  강원포천대리점  서가은  2420000  4740000     4     240

# %%
# 금월 컬럼에서 값이 가장 큰 3개 행 조회

sample_df.nlargest(3, "금월")
# Out:
#    Sap Co.        대리점 영업사원       전월       금월  TEAM  총 판매수량
# 18  KI3131    경기하남대리점  김민정  2750000  7268000     3     293
# 16  KI2910    강원춘천대리점  김은향  4800000  4896000     1     176
# 13  KI2671  제주서귀포시대리점  주은명  4040000  4760000     4      50

# %%
# 금월 컬럼에서 값이 가장 작은 3개 행 조회

sample_df.nsmallest(3, "금월")
# Out:
#    Sap Co.        대리점 영업사원       전월       금월  TEAM  총 판매수량
# 10  KI2313  제주서귀포시대리점  온지수   152000   945000     1      52
# 11  KI2433    경기계양대리점  이희영  1833000  1404000     1     110
# 6   KI1917    경기광주대리점  김진혜  1292000  1518000     1     110

# %%
# 총 판매수량이 250 보다 큰 대리점 조회

sample_df[sample_df['총 판매수량'] > 250]
# Out:
#    Sap Co.       대리점 영업사원       전월       금월  TEAM  총 판매수량
# 2   KI1534   경기화성대리점  경인선   600000  2214000     1     320
# 14  KI2776  경기남양주대리점  김수진  8160000  4352000     2     354
# 18  KI3131   경기하남대리점  김민정  2750000  7268000     3     293

# %%
sample_df[["대리점","금월","총 판매수량"]]
# Out:
#           대리점       금월  총 판매수량
# 0     경기수원대리점  2952000     123
# 1     충청홍성대리점  2706000     220
# 2     경기화성대리점  2214000     320
# 3     강원속초대리점  2870000     110
# 4     경기안양대리점  2296000     134
# 5    제주제주시대리점  2346000     210
# 6     경기광주대리점  1518000     110
# 7     경기평택대리점  2139000      90
# 8    경기의정부대리점  2484000     183
# 9     경기성남대리점  1518000      73
# 10  제주서귀포시대리점   945000      52
# 11    경기계양대리점  1404000     110
# 12    경기평촌대리점  2312000     240
# 13  제주서귀포시대리점  4760000      50
# 14   경기남양주대리점  4352000     354
# 15   경기구리시대리점  3400000     143
# 16    강원춘천대리점  4896000     176
# 17    강원영동대리점  3128000      98
# 18    경기하남대리점  7268000     293
# 19    강원포천대리점  4740000     240

# %%
sample_df.loc[2]
# Out:
# Sap Co.     KI1534
# 대리점        경기화성대리점
# 영업사원           경인선
# 전월          600000
# 금월         2214000
# TEAM             1
# 총 판매수량         320
# Name: 2, dtype: object

# %%
# iloc : index
# 슬랑이싱 : [0:3]

sample_df.iloc[0:5,[1,4,6]]
# Out:
#        대리점       금월  총 판매수량
# 0  경기수원대리점  2952000     123
# 1  충청홍성대리점  2706000     220
# 2  경기화성대리점  2214000     320
# 3  강원속초대리점  2870000     110
# 4  경기안양대리점  2296000     134

# %%
sample_df.loc[0:5,["대리점","금월","총 판매수량"]]
# Out:
#         대리점       금월  총 판매수량
# 0   경기수원대리점  2952000     123
# 1   충청홍성대리점  2706000     220
# 2   경기화성대리점  2214000     320
# 3   강원속초대리점  2870000     110
# 4   경기안양대리점  2296000     134
# 5  제주제주시대리점  2346000     210

# %%
# 컬럼명에 "월" 들어긴 컬럼 조회

sample_df.filter(regex="월")
# Out:
#          전월       금월
# 0   1720000  2952000
# 1   4080000  2706000
# 2    600000  2214000
# 3   3720000  2870000
# 4   4800000  2296000
# 5   3420000  2346000
# 6   1292000  1518000
# 7   2736000  2139000
# 8   1368000  2484000
# 9   1976000  1518000
# 10   152000   945000
# 11  1833000  1404000
# 12  4320000  2312000
# 13  4040000  4760000
# 14  8160000  4352000
# 15  6000000  3400000
# 16  4800000  4896000
# 17  4560000  3128000
# 18  2750000  7268000
# 19  2420000  4740000

# %%
# train 데이터프레임 생성
sample_df2 = pd.read_excel("./data/train.xlsx")
sample_df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 앞 쪽 데이터 5 행 조회
sample_df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 뒤 쪽 데이터 5 행 조회
sample_df2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Fare 컬럼 값 중 가장 큰 4개 행 조회
sample_df2.nlargest(4, "Fare")
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
#
#      Gender   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S

# %%
# Age 컬럼 값이 가장 작은 3행 조회
sample_df2.nsmallest(3, "Age")
# Out:
#      PassengerId  Survived  Pclass                             Name  Gender  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 469  0.75      2      1    2666  19.2583   NaN        C

# %%
# 임의로 추출

sample_df2.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 63            64         0       3                 Skoog, Master. Harald
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 672          673         0       2           Mitchell, Mr. Henry Michael
#
#      Gender   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 63     male   4.0      3      2      347088  27.9000   NaN        S
# 14   female  14.0      0      0      350406   7.8542   NaN        S
# 672    male  70.0      0      0  C.A. 24580  10.5000   NaN        S

# %%
sample_df2.sample()
# Out:
#      PassengerId  Survived  Pclass                            Name Gender  \
# 340          341         1       2  Navratil, Master. Edmond Roger   male
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 340  2.0      1      1  230080  26.0    F2        S

# %%
# 중복 행 제거

sample_df2 = pd.DataFrame({
    "a":[4,5,6,6],
    "b":[7,8,9,9],
    "c":[10,11,12,12]
}, index=['a','b','c','d'])
sample_df2
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12
# d  6  9  12

# %%
# drop_
sample_df2.drop_duplicates(inplace=True)
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12

# %%
friend_dict_list = [
    {
        "name":"John",
        "age":25,
        "job":"student"
    },
    {
        "name":"Nate",
        "age":35,
        "job":"teacher"
    },
    {
        "name":"Jenny",
        "age":30,
        "job":"developer"
    },
]

friend_df = pd.DataFrame(friend_dict_list, index=['s1','s2','s3'])
friend_df
# Out:
#      name  age        job
# s1   John   25    student
# s2   Nate   35    teacher
# s3  Jenny   30  developer

# %%
# and, or : python
a, b, c = 100,60,15
print("and ", a > b and b > c)
print("or ", a > b and b > c)
# Out:
# and  True
# or  True

# %%
# 나이가 25 보다 많고, 이름이 Nate인 사람 조회

# friend_df[(friend_df['age'] > 25) and (friend_df['name'] == 'Nate')] 

friend_df.query("age > 25" and "name == 'Nate'")
# Out:
#     name  age      job
# s2  Nate   35  teacher

# %%
student_list = {
    "name":["John","Nate","Edward","Zara","John"],
    "major":["Computer Science","Computer Science", "Computer Science","Psychology","Computer Science"],
    "gender":["male","male","male","female","male"]
}

student_df = pd.DataFrame(student_list)
student_df
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4    John  Computer Science    male

# %%
# drop_duplicates() : 행이 완벽히 똑같은 경우에만 삭제 됨


student_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
student_list = {
    "name":["John","Nate","Edward","Zara","John"],
    "major":["Computer Science","Computer Science", "Computer Science","Psychology","Economics"],
    "gender":["male","male","male","female","male"]
}

student_df = pd.DataFrame(student_list)
student_df
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4    John         Economics    male

# %%
student_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
student_df.duplicated('name',keep='last')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 student_df.drop_duplicated('name',keep='last')
#
# File c:\source\pythonsource\venv\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_duplicated'

# %%
friend_df
# Out:
#      name  age        job
# s1   John   25    student
# s2   Nate   35    teacher
# s3  Jenny   30  developer

# %%
# Nate 조회

friend_df.iloc[1]
# Out:
# name       Nate
# age          35
# job     teacher
# Name: s2, dtype: object

# %%
friend_df.loc["s2"]
# Out:
# name       Nate
# age          35
# job     teacher
# Name: s2, dtype: object

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------------------- - 7.9/8.1 MB 40.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 34.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 36.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 19.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
iris_df = sns.load_dataset("iris")
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.shape
# Out:
# (150, 5)

# %% [markdown]
# > df.iloc[행,열] : 행, 열의 index 값 이용(마지막 값 미포함)

# %%
# iloc / loc

# 10 ~ 끝
iris_df.iloc[10:21]

# 인덱스 번호 : 1 ~ 3, 컬럼 : sepal_width, petal_length
iris_df.iloc[1:4, 1:3]
# Out:
#    sepal_width  petal_length
# 1          3.0           1.4
# 2          3.2           1.3
# 3          3.1           1.5

# %%
iris_df.iloc[1:4, [1,2,4]]
# Out:
#    sepal_width  petal_length species
# 1          3.0           1.4  setosa
# 2          3.2           1.3  setosa
# 3          3.1           1.5  setosa

# %% [markdown]
# > df.loc[행,열] : 행, 열의 label 값 이용(마지막 값 포함)

# %%
# 마지막 값 포함 

iris_df.loc[1:2]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris_df.loc[1:2,'sepal_width':'petal_width']
# Out:
#    sepal_width  petal_length  petal_width
# 1          3.0           1.4          0.2
# 2          3.2           1.3          0.2

# %%
# 행 1,3 열 : 'sepal_width', 'petal_width'
# loc
iris_df.iloc[[1,3],[1,3]]
# Out:
#    sepal_width  petal_width
# 1          3.0          0.2
# 3          3.1          0.2

# %%
# sepal_width > 3.0

iris_df[iris_df['sepal_width'] > 3.0]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
# [67 rows x 5 columns]

# %%
# sepal_width > 3.0, 열 : 'sepal_width', 'petal_width'

iris_df.loc[iris_df['sepal_width'] > 3.0,['sepal_width', 'petal_width']]
# Out:
#      sepal_width  petal_width
# 0            3.5          0.2
# 2            3.2          0.2
# 3            3.1          0.2
# 4            3.6          0.2
# 5            3.9          0.4
# ..           ...          ...
# 140          3.1          2.4
# 141          3.1          2.3
# 143          3.2          2.3
# 144          3.3          2.5
# 148          3.4          2.3
#
# [67 rows x 2 columns]

# %%
# _ 가 들어있는 컬럼 가져오기
# iris_df.columns

iris_df.filter(regex="_")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# length 가 들어있는 컬럼
iris_df.filter(regex="length")

# length 로 끝나는 컬럼
iris_df.filter(regex="length$")

# sepal 로 시작하는 컬럼
iris_df.filter(regex="^sepal")
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
# &, |, ~, ^
# <,>,<=,>=,==,!=(not equal)
# innull(), notnull()

sample_df2
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12
# d  6  9  12

# %%
# b 컬럼의 값이 7이 아닌 것 조회
sample_df2[sample_df2['b'] != 7]
# Out:
#    a  b   c
# b  5  8  11
# c  6  9  12
# d  6  9  12

# %%
# a, b 컬럼만 추출

sample_df2.loc[sample_df2['b'] != 7,["a","b"]]
# Out:
#    a  b
# b  5  8
# c  6  9
# d  6  9

# %%
# '사과' in ['포도','수박']

# isin() : 포함여부

sample_df2.a.isin([5])
# Out:
# a    False
# b     True
# c    False
# d    False
# Name: a, dtype: bool

# %%
sample_df2 = pd.DataFrame({
    "a":[4,5,6,6,None],
    "b":[7,8,None,9,9],
    "c":[10,11,12,None,12],
}, index=['a','b','c','d','e'])

sample_df2
# Out:
#      a    b     c
# a  4.0  7.0  10.0
# b  5.0  8.0  11.0
# c  6.0  NaN  12.0
# d  6.0  9.0   NaN
# e  NaN  9.0  12.0

# %%
# 널 값 확인

sample_df2.isnull()
# Out:
#        a      b      c
# a  False  False  False
# b  False  False  False
# c  False   True  False
# d  False  False   True
# e   True  False  False

# %%
sample_df2['a'].isnull()
sample_df2['a'].isna()
# Out:
# a    False
# b    False
# c    False
# d    False
# e     True
# Name: a, dtype: bool

# %%
sample_df2['a'].isnull().sum()
sample_df2.isnull().sum()
# Out:
# a    1
# b    1
# c    1
# dtype: int64

# %%
# 널이 아닌 것 
sample_df2.notna()
sample_df2.notnull()
# Out:
#        a      b      c
# a   True   True   True
# b   True   True   True
# c   True  False   True
# d   True   True  False
# e  False   True   True

# %%
sample_df2[sample_df2.notnull()]
# Out:
#      a    b     c
# a  4.0  7.0  10.0
# b  5.0  8.0  11.0
# c  6.0  NaN  12.0
# d  6.0  9.0   NaN
# e  NaN  9.0  12.0

# %%
sample_df2[sample_df2['a'].notnull()]
# Out:
#      a    b     c
# a  4.0  7.0  10.0
# b  5.0  8.0  11.0
# c  6.0  NaN  12.0
# d  6.0  9.0   NaN

# %%
df = pd.DataFrame({
    "name":['Alfred','Batman','Catwoman'],
    "toy":[None,'Batmobile','Bullwhip'],
    "born":[None,pd.Timestamp('19400425'),None],
})
df
# Out:
#        name        toy       born
# 0    Alfred       None        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dtypes
# Out:
# name            object
# toy             object
# born    datetime64[ns]
# dtype: object

# %%
# 결측치 데이터 처리
# 제거
# 임의의 값으로 채우기 

# how : {'any', 'all'}, default 'any' : 하나라도 널 값이 존재하면 제거
# how : 'all' : 전체가 널 값일 때 제거

df.dropna(axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(axis=0)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(axis=0, how='all')
# Out:
#        name        toy       born
# 0    Alfred       None        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
# fillna

df.fillna(0)
# Out:
#        name        toy                 born
# 0    Alfred          0                    0
# 1    Batman  Batmobile  1940-04-25 00:00:00
# 2  Catwoman   Bullwhip                    0

# %%
df.fillna({"name":"noname","toy":"Bat","born":pd.Timestamp('2000-01-01')})
# Out:
#        name        toy       born
# 0    Alfred        Bat 2000-01-01
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip 2000-01-01

# %%
student_list = {
    "name":["John","Nate","Edward","Zara","John"],
    "major":["Computer Science","Computer Science", "Computer Science","Psychology","Computer Science"],
    "gender":["male","male","male","female","male"],
    "age":[40,35,None,10,None]
}

student_df = pd.DataFrame(student_list)
student_df
# Out:
#      name             major  gender   age
# 0    John  Computer Science    male  40.0
# 1    Nate  Computer Science    male  35.0
# 2  Edward  Computer Science    male   NaN
# 3    Zara        Psychology  female  10.0
# 4    John  Computer Science    male   NaN

# %%
# Edward, John : major 같은 사람들의 평균 값으로 채우기
# sql 과 동일 : groupby

student_df.groupby('major')['age'].median()
# Out:
# major
# Computer Science    37.5
# Psychology          10.0
# Name: age, dtype: float64

# %%
student_df["age"].fillna(student_df.groupby('major')['age'].transform('median'),inplace=True)

# %%
student_df
# Out:
#      name             major  gender   age
# 0    John  Computer Science    male  40.0
# 1    Nate  Computer Science    male  35.0
# 2  Edward  Computer Science    male  37.5
# 3    Zara        Psychology  female  10.0
# 4    John  Computer Science    male  37.5

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# species 종류별 데이터 개수

iris_df['species'].value_counts()
iris_df['sepal_width'].value_counts()
# Out:
# sepal_width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.3     6
# 3.5     6
# 3.8     6
# 2.6     5
# 3.6     4
# 2.3     4
# 3.7     3
# 2.2     3
# 2.4     3
# 3.9     2
# 4.4     1
# 4.2     1
# 4.1     1
# 4.0     1
# 2.0     1
# Name: count, dtype: int64

# %%
species_df = pd.DataFrame(iris_df['species'].value_counts())
species_df
# Out:
#             count
# species
# setosa         50
# versicolor     50
# virginica      50

# %%
# 행 갯수

iris_df.shape[0]
len(iris_df)
# Out:
# 150

# %%
# unique

iris_df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# unique 한 요소 개수

iris_df['species'].nunique()
# Out:
# 3

# %%
# describe() : 기술통계요약 => 숫자 컬럼만 해줌

iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.sum()
# Out:
# sepal_length                                                876.5
# sepal_width                                                 458.6
# petal_length                                                563.7
# petal_width                                                 179.9
# species         setosasetosasetosasetosasetosasetosasetosaseto...
# dtype: object

# %%
iris_df['sepal_length'].sum()
# Out:
# np.float64(876.5)

# %%
iris_df.count()
iris_df['sepal_length'].count()
# Out:
# np.int64(150)

# %%
# 평균(mean) : 
# 중앙값(median) : 

iris_df.mean(numeric_only=True)
iris_df.median(numeric_only=True)
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
iris_df.quantile([0.25,0.75],numeric_only=True)
# Out:
#       sepal_length  sepal_width  petal_length  petal_width
# 0.25           5.1          2.8           1.6          0.3
# 0.75           6.4          3.3           5.1          1.8

# %%
iris_df.max()
iris_df.min()
iris_df.var(numeric_only=True)  # 분산
iris_df.std(numeric_only=True)  # 표준편차
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %%
# train
# 기술통계요약정보
sample_df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 생존자 나이 평균
sample_df2[sample_df2['Survived'] == 1]["Age"].mean()
# Out:
# np.float64(28.343689655172415)

# %%
# 생존자 중 제일 많은 나이

sample_df2[sample_df2['Survived'] == 1]["Age"].max()
# Out:
# np.float64(80.0)
