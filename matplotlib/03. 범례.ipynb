# %% [markdown]
# ## matplotlib (https://matplotlib.org/stable/index)
#
# - 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %% [markdown]
# ### 범례 설정
# - https://matplotlib.org/stable/api/legend_api.html

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
x = [1,2,3]
y = [2,4,8]

# %%
# 범례 설정
plt.plot(x, y, label="데이터")
ㅎ = plt.legend()

# %% [markdown]
# - 두 개의 선을 하나의 차트에 그릴 때

# %%
x1 = [1,2,3]
y1 = [1,2,3]
x2 = [1,2,3]
y2 = [1,4,7]

plt.plot(x1, y1, color='yellow', label='data1')
plt.plot(x2, y2, color="green", label='data2')
gta = plt.legend()

# %%
plt.plot(x1, y1, color='yellow', label='data1')
plt.plot(x2, y2, color="green", label='data2')
gta = plt.legend(['data1', 'data2'])

# %% [markdown]
# ><b>1) 범례 위치 설정</b>

# %% [markdown]
# - 범례 위치 지정하기 - 기본은 5
# - 0 or 아무값도 안 주면 그래프에 따라 자동으로 위치 지정
#
# <table border="1" align="left">
#     <tr>
#         <td>2(upper left)</td>
#         <td>9(upper center)</td>
#         <td>1(upper right)</td>
#     </tr>
#     <tr>
#         <td>6(center left)</td>
#         <td>10(center)</td>
#         <td>5(right),7(center right)</td>
#     </tr>
#     <tr>
#         <td>3(lower left)</td>
#         <td>8(lower center)</td>
#         <td>4(lower right)</td>
#     </tr>
# </table>
#
# <br><br>

# %%
plt.plot(x, y)
a = plt.legend(['데이터'], loc="upper right")

# %%
plt.plot(x, y)
a = plt.legend(['데이터'], loc="upper center")

# %%
plt.plot(x, y)
# a = plt.legend(['데이터'], loc="center")
a = plt.legend(['데이터'], loc=(0.7,0.3)) # 0 ~ 1 사이값

# %% [markdown]
# ><b>2) 범례 폰트 사이즈 지정</b>

# %%
plt.plot(x1, y1, color='yellow', label='data1')
plt.plot(x2, y2, color="green", label='data2')
gta = plt.legend(fontsize=20)

# %% [markdown]
# ><b>3) 범례 행 수 지정</b>

# %%
plt.plot(x1, y1, color='yellow', label='data1')
plt.plot(x2, y2, color="green", label='data2')
gta = plt.legend(ncol=2)

# %% [markdown]
# - [문제] : data1(x : 1, 2, 3; y : 1, 2, 3) 과 data2(x : 1, 2, 3; y : 1, 100, 200) 을 그래프로 출력하시오.

# %%
x1 = [1, 2, 3]
y1 = [1, 2, 3]
x2 = [1, 2, 3]
y2 = [1, 100, 200]

# %%
plt.plot(x1, y1, color='blue')
g = plt.plot(x2, y2, color="red")
